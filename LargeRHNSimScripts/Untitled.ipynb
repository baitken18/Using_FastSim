# %%
import pickle
import numpy as np
import awkward as ak

# %%
fname = 'Finished_Sim_Ue/sim_Ue_Bmeson_2.14788_2.275845926074791e-10.pickle'
with open(fname, 'rb') as f:
    data = pickle.load(f)['Data']

# %%
import sys
sys.path.insert(0,'../MomentumExtrapolation/')
from Opening_Angle_Histogram import calculate_opening_angle
from Closest_Approach_Histogram import calculate_shortest_distance

# %%
out = calculate_opening_angle(data)

# %%
out[0]
# Out:
# masked_array(data=[0.37647961, 0.7661983 , 0.88613501, ..., 1.22800046,
#                    1.68562218, 0.22152525],
#              mask=False,
#        fill_value=1e+20)

# %%
calculate_shortest_distance(data)
# Out:
# (array([34.89389502,  2.53662276, 40.82107974, ...,  5.9811844 ,
#         91.03452995, 14.63528859]),
#  <Array [True, True, True, False, ..., False, False, True] type='35498 * bool'>)

# %%
data['weight'] = data['weight'] / 2.275845926074791e-10

# %%
from make_plots import make_opening_histogram

# %%
make_opening_histogram(data, fname)
# Out:
# <Axes: title={'center': 'MATHUSLA100 No Walls Geometry (Luminosity = 3000 fb$^{-1}$)'}, xlabel='Maximum Opening Angle [$\\pi$ rad]', ylabel='Number of Vertices'>

# %%
from make_plots import make_closest_histogram

# %%
make_closest_histogram(data, fname)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 make_closest_histogram(data, fname)
#
# File ~\Documents\5thYear\Phys499\Using_FastSim\LargeRHNSimScripts\make_plots.py:87, in make_closest_histogram(data, outfile, ax, log)
#      84 ax.errorbar(h.axes[0].centers, h.view().value, yerr = np.sqrt(h.view().variance), fmt = '.', color = l[0].get_color())
#      86 if outfile != None:
# ---> 87     plt.savefig(outfile)
#      89     plt.close()
#      91 return ax
#
# File ~\anaconda3\envs\spyder\Lib\site-packages\matplotlib\pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# ...
